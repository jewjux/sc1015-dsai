# %%
import pandas as pd
import requests
import io

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jewjux/sc1015-dsai/main/kmodes_cluster.csv")
kmodes = df.drop(columns=['Unnamed: 0'])

df2 = pd.read_csv("https://raw.githubusercontent.com/jewjux/sc1015-dsai/main/kmeans.csv")
df3 = df2.drop(columns=['Unnamed: 0'])
df4 = df3.drop([227])
kmeans = df4.reset_index(drop=False)

df5 =  pd.read_csv("cleaned_1015.csv")
df6 = df5.drop([227])
original = df6.reset_index(drop=False)

# %%
df6 = original.drop(columns = ["Unnamed: 0"])
df6["kmodes_cluster"] = kmodes["Cluster"]
df6["kmeans_cluster"] = kmeans["cluster"]
final = df6.drop(columns = ["index"])
final
# Out:
#                              TITLE      ID  VOTE_AVERAGE     BUDGET  \
# 0                           Avatar   19995           7.6  237000000
# 1                Avengers: Endgame  299534           8.3  356000000
# 2         Avatar: The Way of Water   76600           7.7  460000000
# 3                          Titanic     597           7.9  200000000
# 4     Star Wars: The Force Awakens  140607           7.3  245000000
# ...                            ...     ...           ...        ...
# 6965             At Long Last Love    4704           5.5    6000000
# 6966               Under Capricorn    4175           6.0    2500000
# 6967                 Stolen Kisses     255           7.3     350000
# 6968            To Be or Not to Be     198           7.9    1200000
# 6969                     The Raven   29056           6.4     350000
#
#          REVENUE DECADE_RELEASED       MAIN_GENRE  kmodes_cluster  \
# 0     2920357254           2000s           Action               0
# 1     2799439100           2010s        Adventure               2
# 2     2293000000           2020s  Science Fiction               0
# 3     2187463944           1990s            Drama               0
# 4     2068223624           2010s        Adventure               2
# ...          ...             ...              ...             ...
# 6965     1500000           1970s           Comedy               1
# 6966     1500000    Before 1960s            Crime               0
# 6967     1500000           1960s           Comedy               1
# 6968     1500000    Before 1960s           Comedy               1
# 6969     1499275           1960s           Comedy               1
#
#       kmeans_cluster
# 0                  3
# 1                  3
# 2                  3
# 3                  3
# 4                  3
# ...              ...
# 6965               1
# 6966               1
# 6967               1
# 6968               1
# 6969               1
#
# [6970 rows x 9 columns]

# %%
#Function for getting all possible recommendations
def find_equals(userinput):
    try:
        index = final.index[final['TITLE'] == userinput].tolist()
        value1 = index[0]
        kmodes_cluster_no = (final.loc[value1]["kmodes_cluster"])
        kmeans_cluster_no = (final.loc[value1]["kmeans_cluster"])
        recommend = final[(final["kmodes_cluster"] == kmodes_cluster_no) & (final["kmeans_cluster"] == kmeans_cluster_no)]
        return recommend
    except:
        print("Movie not in database. Try another movie.")

#Function for processing recommendations
def recommendations(table):
    actual_list = table['TITLE'].values.tolist()
    return actual_list

# %%
index = final.index[final['TITLE'] == "Star Wars: The Force Awakens"].tolist()
value1 = index[0]
kmodes_cluster_no = (final.loc[value1]["kmodes_cluster"])
kmeans_cluster_no = (final.loc[value1]["kmeans_cluster"])

recommend = final[(final["kmodes_cluster"] == kmodes_cluster_no) & (final["kmeans_cluster"] == kmeans_cluster_no)]
actual_list = recommend['TITLE'].values.tolist()
actual_list

# %%
#User interface functions
def user_intro():
    print("Welcome to movie recommendation database")
    print()
    print("1: Input movie")
    print("2: Exit")
    print()
    
def interface():
    #Introduction
    user_intro()
    
    choice = input("Please choose an option ")
    
    while choice != "1": 
        if choice == "2":
            print("Thank you for using the database. Feel free to suggest improvements.")
            break 
            
        else:
            print("Invalid input. Please try again.")
            print()
            choice = input("Please choose an option ")
            
    if choice == "1":
        userInput = input("Please input movie you want recommendations to be made from (Follow exact wording from TMDB website) ")
        x = find_equals(userInput)
        y = recommendations(x)
        j = 0
        anymore = True
        breaking = True
        print("Here are some suggestions")
        print()
        for i in range(10):
            try:
                print(y[j])
                j += 1
            except:
                print("Sorry no more movies to recommend")
                break
        
        continue_input = input("Would you like any more recommendations? (Y/N) ")
        while True:
            if continue_input == "Y":
                for i in range(10):
                    try:
                        print(y[j])
                        j += 1
                    except:
                        print("Sorry no more movies to recommend")
                        print()
                        anymore = False
                        break
                        
                if anymore == True:
                    print()
                    continue_input = input("Would you like any more recommendations? (Y/N) ")
                
                else:
                    continue_input = "N"
                    continue

            elif continue_input == "N":
                    print("Thank you for using the database. Feel free to suggest improvements.")
                    break

            else:
                print("Invalid input. Please try again.")
                continue_input = input("Would you like any more recommendations? ")

# %%
interface()
# Out:
# Welcome to movie recommendation database
#
# 1: Input movie
# 2: Exit
#
# Please choose an option 1
# Please input movie you want recommendations to be made from (Follow exact wording from TMDB website) Avatar: The Way of Water
# Here are some suggestions
#
# Avatar
# Avatar: The Way of Water
# Titanic
# Spider-Man: No Way Home
# Jurassic World
# Furious 7
# Top Gun: Maverick
# Avengers: Age of Ultron
# Black Panther
# Jurassic World: Fallen Kingdom
# Would you like any more recommendations? (Y/N) Y
# Incredibles 2
# The Fate of the Furious
# Iron Man 3
# Aquaman
# Spider-Man: Far From Home
# Captain Marvel
# Transformers: Dark of the Moon
# Skyfall
# The Dark Knight Rises
# Rogue One: A Star Wars Story
#
# Would you like any more recommendations? (Y/N) Y
# Jurassic World Dominion
# The Hobbit: The Battle of the Five Armies
# Doctor Strange in the Multiverse of Madness
# Spectre
# Spider-Man: Homecoming
# Batman v Superman: Dawn of Justice
# Black Panther: Wakanda Forever
# Thor: Ragnarok
# Inception
# Wonder Woman
#
# Would you like any more recommendations? (Y/N) Y
# Fantastic Beasts and Where to Find Them
# Mission: Impossible - Fallout
# 2012
# Fast & Furious 6
# Spider-Man 2
# No Time to Die
# Guardians of the Galaxy
# The Batman
# Thor: Love and Thunder
# Fast & Furious Presents: Hobbs & Shaw
#
# Would you like any more recommendations? (Y/N) Y
# The Amazing Spider-Man
# X-Men: Days of Future Past
# Suicide Squad
# F9
# Captain America: The Winter Soldier
# The Amazing Spider-Man 2
# Mission: Impossible - Ghost Protocol
# Mission: Impossible - Rogue Nation
# Doctor Strange
# Man of Steel
#
# Would you like any more recommendations? (Y/N) Y
# Justice League
# The Hunger Games: Mockingjay - Part 2
# Thor: The Dark World
# The Battle at Lake Changjin: Water Gate Bridge
# Men in Black 3
# Ant-Man and the Wasp
# Transformers: The Last Knight
# Iron Man
# Kong: Skull Island
# Armageddon
#
# Would you like any more recommendations? (Y/N) Y
# X-Men: Apocalypse
# World War Z
# The Meg
# Godzilla
# Kung Fu Panda 3
# Godzilla vs. Kong
# Star Trek Into Darkness
# Pokémon Detective Pikachu
# Pearl Harbor
# Ant-Man and the Wasp: Quantumania
#
# Would you like any more recommendations? (Y/N) Y
# Men in Black II
# Terminator 3: Rise of the Machines
# Warcraft
# Shang-Chi and the Legend of the Ten Rings
# Mega Man X: The Day of Sigma
# Pacific Rim
# Fantastic Beasts: The Secrets of Dumbledore
# Alita: Battle Angel
# Eternals
# Dune
#
# Would you like any more recommendations? (Y/N) Y
# Black Adam
# Independence Day: Resurgence
# Black Widow
# Mad Max: Fury Road
# Batman Begins
# Terminator Salvation
# Captain America: The First Avenger
# Edge of Tomorrow
# Tenet
# X-Men: First Class
#
# Would you like any more recommendations? (Y/N) Y
# Star Trek Beyond
# The Great Wall
# Robin Hood
# The Last Airbender
# Pacific Rim: Uprising
# Lethal Weapon 4
# John Carter
# Waterworld
# The Lone Ranger
# Rush Hour 3
#
# Would you like any more recommendations? (Y/N) Y
# Dolittle
# Ghostbusters
# Lightyear
# Wild Wild West
# Jungle Cruise
# White House Down
# Cowboys & Aliens
# The Suicide Squad
# Wonder Woman 1984
# Speed 2: Cruise Control
#
# Would you like any more recommendations? (Y/N) Y
# Space Jam: A New Legacy
# The Matrix Resurrections
# Gods of Egypt
# King Arthur: Legend of the Sword
# Onward
# Soul
# Strange World
# Moonfall
# Mulan
# The 13th Warrior
#
# Would you like any more recommendations? (Y/N) Y
# Luca
# Turning Red
# The Tomorrow War
# Sorry no more movies to recommend
#
# Thank you for using the database. Feel free to suggest improvements.
